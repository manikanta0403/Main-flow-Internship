# %% [markdown]
# <a href="https://colab.research.google.com/github/manikanta0403/Main-flow-Internship/blob/main/Task_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Exploratory Data Analysis**

# %% [markdown]
# **->Data Overview**

# %%
import pandas as pd

# Sample data
data = {
    'Id': [1, 2, 3, 4, 5, 6],
    'LotArea': [8450, 9600, 11250, 9550, 14260, 14115],
    'YearBuilt': [2003, 1976, 2001, 1915, 2000, 1993],
    'TotalRooms': [8, 6, 7, 9, 7, 5],
    'BedroomAbvGr': [3, 3, 3, 4, 3, 3],
    'FullBath': [2, 2, 2, 1, 2, 2],
    'SalePrice': [208500, 181500, 223500, 140000, 250000, 143000]
}

# Load data into DataFrame
df = pd.DataFrame(data)

# Display the first few rows
print(df.head())

# Display basic information
print(df.info())
# Out:
#    Id  LotArea  YearBuilt  TotalRooms  BedroomAbvGr  FullBath  SalePrice
# 0   1     8450       2003           8             3         2     208500
# 1   2     9600       1976           6             3         2     181500
# 2   3    11250       2001           7             3         2     223500
# 3   4     9550       1915           9             4         1     140000
# 4   5    14260       2000           7             3         2     250000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            6 non-null      int64
#  1   LotArea       6 non-null      int64
#  2   YearBuilt     6 non-null      int64
#  3   TotalRooms    6 non-null      int64
#  4   BedroomAbvGr  6 non-null      int64
#  5   FullBath      6 non-null      int64
#  6   SalePrice     6 non-null      int64
# dtypes: int64(7)
# memory usage: 464.0 bytes
# None

# %% [markdown]
# **->Summary Statistics**

# %%
# Summary statistics for numerical variables
print(df.describe())
# Out:
#              Id       LotArea    YearBuilt  TotalRooms  BedroomAbvGr  \
# count  6.000000      6.000000     6.000000    6.000000      6.000000
# mean   3.500000  11204.166667  1981.333333    7.000000      3.166667
# std    1.870829   2478.234082    33.968613    1.414214      0.408248
# min    1.000000   8450.000000  1915.000000    5.000000      3.000000
# 25%    2.250000   9562.500000  1980.250000    6.250000      3.000000
# 50%    3.500000  10425.000000  1996.500000    7.000000      3.000000
# 75%    4.750000  13398.750000  2000.750000    7.750000      3.000000
# max    6.000000  14260.000000  2003.000000    9.000000      4.000000
#
#        FullBath      SalePrice
# count  6.000000       6.000000
# mean   1.833333  191083.333333
# std    0.408248   44359.234289
# min    1.000000  140000.000000
# 25%    2.000000  152625.000000
# 50%    2.000000  195000.000000
# 75%    2.000000  219750.000000
# max    2.000000  250000.000000

# %% [markdown]
# **->Missing Values**

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Id              0
# LotArea         0
# YearBuilt       0
# TotalRooms      0
# BedroomAbvGr    0
# FullBath        0
# SalePrice       0
# dtype: int64

# %% [markdown]
# **->UnivariateAnalysis**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram for numerical variables
df.hist(figsize=(12, 10))
plt.show()

# Boxplot for numerical variables
df.plot(kind='box', subplots=True, layout=(3, 3), figsize=(12, 10))
plt.show()

# %% [markdown]
# **->Bivariate Analysis**

# %%
# Scatter plot for numerical variables
sns.pairplot(df)
plt.show()

# Bar plot for categorical variables (in this sample, only 'BedroomAbvGr' can be considered categorical)
sns.barplot(x='BedroomAbvGr', y='SalePrice', data=df)
plt.show()

# %% [markdown]
# **->Multivariate Analysis**

# %%
# Heatmap for correlation matrix
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# **->Outliers Detection**

# %%
# Boxplot for outliers detection
sns.boxplot(data=df)
plt.show()

# IQR method for outliers detection
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
outliers = ((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).sum()
print(outliers)
# Out:
# Id              0
# LotArea         0
# YearBuilt       1
# TotalRooms      0
# BedroomAbvGr    1
# FullBath        1
# SalePrice       0
# dtype: int64

# %% [markdown]
# **->Correlation Analysis**

# %%
# Correlation matrix
correlation_matrix = df.corr()
print(correlation_matrix)

# Heatmap for correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()
# Out:
#                     Id   LotArea  YearBuilt  TotalRooms  BedroomAbvGr  \
# Id            1.000000  0.875796  -0.100709   -0.377964      0.130931
# LotArea       0.875796  1.000000   0.357586   -0.586632     -0.326996
# YearBuilt    -0.100709  0.357586   1.000000   -0.537065     -0.956664
# TotalRooms   -0.377964 -0.586632  -0.537065    1.000000      0.692820
# BedroomAbvGr  0.130931 -0.326996  -0.956664    0.692820      1.000000
# FullBath     -0.130931  0.326996   0.956664   -0.692820     -1.000000
# SalePrice    -0.247625  0.170046   0.662764    0.066950     -0.564158
#
#               FullBath  SalePrice
# Id           -0.130931  -0.247625
# LotArea       0.326996   0.170046
# YearBuilt     0.956664   0.662764
# TotalRooms   -0.692820   0.066950
# BedroomAbvGr -1.000000  -0.564158
# FullBath      1.000000   0.564158
# SalePrice     0.564158   1.000000
